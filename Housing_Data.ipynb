# %%
import pandas as pd

# %%
forsale_data = "Resources1/Forsale_inventory.csv"
homevalue_index = "Resources1/Homevalue_index.csv"
homevalue_forecast = "Resources1/Homevalue_forecast.csv"
newlisting_inv = "Resources1/Newlisting_inventory.csv"

# %%
# Create a DataFrame for the all the data sets . 
forsale_data_df = pd.read_csv(forsale_data)
homevalue_index_df = pd.read_csv(homevalue_index, index_col = False)
homevalue_forecast_df = pd.read_csv(homevalue_forecast)
newlisting_inv_df = pd.read_csv(newlisting_inv)

# %% [markdown]
# ### Homevalue_index

# %%
# Drop dates from 2000-2017
#forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank', '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31'], axis = 1
homevalue_index_df.drop(homevalue_index_df.iloc[:, 5:221], inplace=True, axis=1)

# %%
homevalue_index_df= homevalue_index_df.drop(['RegionType', 'SizeRank'], axis = 1)
homevalue_index_df
# Out:
#      RegionID                          RegionName StateName  2018-01-31  \
# 0      102001                       United States       NaN    227454.0
# 1      394913                        New York, NY        NY    457787.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA        CA    640399.0
# 3      394463                         Chicago, IL        IL    233362.0
# 4      394514               Dallas-Fort Worth, TX        TX    235051.0
# ..        ...                                 ...       ...         ...
# 904    394767                          Lamesa, TX        TX     66541.0
# 905    753874                           Craig, CO        CO    208249.0
# 906    394968                           Pecos, TX        TX         NaN
# 907    395188                          Vernon, TX        TX     65714.0
# 908    394743                       Ketchikan, AK        AK    292161.0
#
#      2018-02-28  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  \
# ...

# %%
#Dropping rows with null values 
homevalue_index_dfnew = homevalue_index_df.dropna()
homevalue_index_dfnew
# Out:
#      RegionID                          RegionName StateName  2018-01-31  \
# 1      394913                        New York, NY        NY    457787.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA        CA    640399.0
# 3      394463                         Chicago, IL        IL    233362.0
# 4      394514               Dallas-Fort Worth, TX        TX    235051.0
# 5      394974                    Philadelphia, PA        PA    233301.0
# ..        ...                                 ...       ...         ...
# 890    394805                      Los Alamos, NM        NM    277863.0
# 892    394841                       Maysville, KY        KY     87655.0
# 900    395142                      Sweetwater, TX        TX     74285.0
# 902    753929                          Zapata, TX        TX     89025.0
# 908    394743                       Ketchikan, AK        AK    292161.0
#
#      2018-02-28  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  \
# ...

# %% [markdown]
# ### FORSALE_INVENTORY

# %%
# Drop irrelevant columns
forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank'], axis = 1)

# %%
#Dropping rows with null values 
forsale_data_dfnew = forsale_data_df.dropna()
forsale_data_dfnew
# Out:
#      RegionID                          RegionName StateName  2018-01-31  \
# 1      394913                        New York, NY        NY     68959.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA        CA     20082.0
# 3      394463                         Chicago, IL        IL     42828.0
# 4      394514               Dallas-Fort Worth, TX        TX     24290.0
# 5      394974                    Philadelphia, PA        PA     26493.0
# ..        ...                                 ...       ...         ...
# 912    394767                          Lamesa, TX        TX        28.0
# 913    753874                           Craig, CO        CO       120.0
# 914    394968                           Pecos, TX        TX        13.0
# 915    395188                          Vernon, TX        TX        19.0
# 916    394743                       Ketchikan, AK        AK        63.0
#
#      2018-02-28  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  \
# ...

# %% [markdown]
# ### Newlisting_inventory

# %%
# Drop irrelevant columns
newlisting_inv_df = newlisting_inv_df.drop(['RegionType', 'SizeRank'], axis = 1)

# %%
#Dropping rows with null values 
newlisting_inv_dfnew = newlisting_inv_df.dropna()
newlisting_inv_dfnew
# Out:
#      RegionID                          RegionName StateName  2018-03-31  \
# 1      394913                        New York, NY        NY     13884.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA        CA     12378.0
# 3      394463                         Chicago, IL        IL     19087.0
# 4      394514               Dallas-Fort Worth, TX        TX      9728.0
# 5      394974                    Philadelphia, PA        PA      7957.0
# ..        ...                                 ...       ...         ...
# 905    395112                     Spirit Lake, IA        IA         4.0
# 906    753925                  Vineyard Haven, MA        MA        26.0
# 907    753927                      Winnemucca, NV        NV         9.0
# 908    395142                      Sweetwater, TX        TX         4.0
# 913    753874                           Craig, CO        CO        22.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# ...
