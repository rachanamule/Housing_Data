# %%
import pandas as pd

# %%
median_price_df = pd.read_csv('2017-2019_price.csv')
median_price_df.head()
# Out:
#                            RegionName  2017-01-31  2017-02-28  2017-03-31  \
# 0                        New York, NY    386000.0    387000.0    387000.0
# 1  Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# 2                         Chicago, IL    211333.0    211333.0    216200.0
# 3               Dallas-Fort Worth, TX    236500.0    239000.0    242333.0
# 4                    Philadelphia, PA    226333.0    221333.0    217667.0
#
#    2017-04-30  2017-05-31  2017-06-30  2017-07-31  2017-08-31  2017-09-30  \
# 0    390333.0    395000.0    406667.0    420000.0    426667.0    425000.0
# 1    589165.0    602498.0    609667.0    615000.0    617917.0    619583.0
# 2    224867.0    234833.0    241800.0    243467.0    240900.0    233400.0
# 3    249667.0    256667.0    261333.0    261643.0    259583.0    254917.0
# 4    222000.0    231000.0    243633.0    249300.0    250967.0    243000.0
#
#    ...  2019-03-31  2019-04-30  2019-05-31  2019-06-30  2019-07-31  \
# ...

# %%
df = median_price_df.set_index('RegionName')
df['2017']=None
df
# Out:
#                                     2017-01-31  2017-02-28  2017-03-31  \
# RegionName
# New York, NY                          386000.0    387000.0    387000.0
# Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# Chicago, IL                           211333.0    211333.0    216200.0
# Dallas-Fort Worth, TX                 236500.0    239000.0    242333.0
# Philadelphia, PA                      226333.0    221333.0    217667.0
# ...                                        ...         ...         ...
# Daytona Beach, FL                     174667.0    173000.0    174667.0
# Des Moines, IA                        181667.0    179333.0    177867.0
# Provo, UT                             258300.0    261633.0    262550.0
# Durham, NC                            237667.0    240750.0    238583.0
# Fort Collins, CO                      342650.0    345783.0    345783.0
#
#                                     2017-04-30  2017-05-31  2017-06-30  \
# RegionName
# ...

# %%
avg = []
for x in range(len(df)):
    #print(df.iloc[x,1])
    #city_avg = []
    #for y in range(12):
        #city_avg.append(df_2017.iloc[x,y])
    avg.append(int((df.iloc[x, 1] + df.iloc[x, 2] + df.iloc[x, 3] + df.iloc[x, 4] + df.iloc[x, 5] + df.iloc[x, 6] + df.iloc[x, 7] + df.iloc[x, 8] + df.iloc[x, 9] + df.iloc[x, 10] + df.iloc[x, 11] + df.iloc[x, 12]) / 12))
df['2017']= avg
#avg
avg_2018 = []
for x in range(len(df)):
    #print(df.iloc[x,1])
    #city_avg = []
    #for y in range(12):
        #city_avg.append(df_2017.iloc[x,y])
    avg_2018.append(int((df.iloc[x, 13] + df.iloc[x, 14] + df.iloc[x, 15] + df.iloc[x, 16] + df.iloc[x, 17] + df.iloc[x, 18] + df.iloc[x, 19] + df.iloc[x, 20] + df.iloc[x, 21] + df.iloc[x, 22] + df.iloc[x, 23] + df.iloc[x, 24]) / 12))
df['2018']= avg_2018
avg_2019 = []
for x in range(len(df)):
    #print(df.iloc[x,1])
    #city_avg = []
    #for y in range(12):
        #city_avg.append(df_2017.iloc[x,y])
    avg_2019.append(int((df.iloc[x, 25] + df.iloc[x, 26] + df.iloc[x, 27] + df.iloc[x, 28] + df.iloc[x, 29] + df.iloc[x, 30] + df.iloc[x, 31] + df.iloc[x, 32] + df.iloc[x, 33] + df.iloc[x, 34] + df.iloc[x, 35] + df.iloc[x, 36]) / 12))
df['2019']= avg_2019

# %%
df
# Out:
#                                     2017-01-31  2017-02-28  2017-03-31  \
# RegionName
# New York, NY                          386000.0    387000.0    387000.0
# Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# Chicago, IL                           211333.0    211333.0    216200.0
# Dallas-Fort Worth, TX                 236500.0    239000.0    242333.0
# Philadelphia, PA                      226333.0    221333.0    217667.0
# ...                                        ...         ...         ...
# Daytona Beach, FL                     174667.0    173000.0    174667.0
# Des Moines, IA                        181667.0    179333.0    177867.0
# Provo, UT                             258300.0    261633.0    262550.0
# Durham, NC                            237667.0    240750.0    238583.0
# Fort Collins, CO                      342650.0    345783.0    345783.0
#
#                                     2017-04-30  2017-05-31  2017-06-30  \
# RegionName
# ...

# %%
df.drop(df.iloc[:, 0:6], inplace=True, axis=1)
df
# Out:
#                                       2017    2018    2019
# RegionName
# New York, NY                        404416  414097  419020
# Los Angeles-Long Beach-Anaheim, CA  605312  640611  646689
# Chicago, IL                         228044  233166  238503
# Dallas-Fort Worth, TX               252901  263851  269364
# Philadelphia, PA                    234019  239058  247939
# ...                                    ...     ...     ...
# Daytona Beach, FL                   186527  206338  219387
# Des Moines, IA                      190244  202523  211494
# Provo, UT                           272914  300699  317779
# Durham, NC                          255641  274868  284250
# Fort Collins, CO                    353237  381585  387414
#
# [94 rows x 3 columns]

# %%
df.to_csv('saleprice_2017_avg.csv')
