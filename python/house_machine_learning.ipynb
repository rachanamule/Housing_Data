# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import datetime 
from sqlalchemy import create_engine
from config import db_password

# %%
"postgresql://[user]:[password]@[location]:[port]/[database]"
# Out:
# 'postgresql://[user]:[password]@[location]:[port]/[database]'

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/housing_data"

# %%
engine = create_engine(db_string)

# %%
# Import our input dataset
avg_df = pd.read_csv('2017-2019_price.csv')
avg_df.head(10)
# Out:
#                            RegionName     1/31/2017     2/28/2017  \
# 0                        New York, NY  $386,000.00   $387,000.00
# 1  Los Angeles-Long Beach-Anaheim, CA  $571,833.00   $570,167.00
# 2                         Chicago, IL  $211,333.00   $211,333.00
# 3               Dallas-Fort Worth, TX  $236,500.00   $239,000.00
# 4                    Philadelphia, PA  $226,333.00   $221,333.00
# 5                         Houston, TX  $218,333.00   $217,000.00
# 6                      Washington, DC  $378,124.00   $377,791.00
# 7           Miami-Fort Lauderdale, FL  $255,000.00   $253,333.00
# 8                         Atlanta, GA  $210,667.00   $210,667.00
# 9                          Boston, MA  $398,833.00   $393,833.00
#
#       3/31/2017     4/30/2017     5/31/2017     6/30/2017     7/31/2017  \
# 0  $387,000.00   $390,333.00   $395,000.00   $406,667.00   $420,000.00
# 1  $577,498.00   $589,165.00   $602,498.00   $609,667.00   $615,000.00
# 2  $216,200.00   $224,867.00   $234,833.00   $241,800.00   $243,467.00
# 3  $242,333.00   $249,667.00   $256,667.00   $261,333.00   $261,643.00
# 4  $217,667.00   $222,000.00   $231,000.00   $243,633.00   $249,300.00
# 5  $217,740.00   $223,574.00   $228,574.00   $231,833.00   $232,667.00
# 6  $373,084.00   $381,874.00   $394,540.00   $405,895.00   $408,648.00
# 7  $252,500.00   $255,867.00   $260,533.00   $268,033.00   $272,000.00
# 8  $211,667.00   $217,000.00   $222,023.00   $225,566.00   $227,566.00
# 9  $398,333.00   $401,667.00   $415,000.00   $425,550.00   $434,717.00
#
#       8/31/2017     9/30/2017  ...     3/31/2019     4/30/2019     5/31/2019  \
# 0  $426,667.00   $425,000.00   ...  $407,500.00   $407,500.00   $410,833.00
# 1  $617,917.00   $619,583.00   ...  $633,167.00   $643,931.00   $649,098.00
# 2  $240,900.00   $233,400.00   ...  $228,667.00   $236,000.00   $244,000.00
# 3  $259,583.00   $254,917.00   ...  $259,193.00   $265,823.00   $272,823.00
# 4  $250,967.00   $243,000.00   ...  $231,884.00   $236,584.00   $245,918.00
# 5  $231,667.00   $229,333.00   ...  $232,227.00   $238,333.00   $244,333.00
# 6  $405,948.00   $397,596.00   ...  $398,000.00   $407,012.00   $417,897.00
# 7  $275,667.00   $272,333.00   ...  $279,750.00   $283,167.00   $286,929.00
# 8  $226,543.00   $223,167.00   ...  $242,165.00   $246,333.00   $253,667.00
# 9  $436,383.00   $428,500.00   ...  $437,900.00   $441,633.00   $458,233.00
#
#       6/30/2019     7/31/2019     8/31/2019     9/30/2019    10/31/2019  \
# 0  $421,667.00   $431,667.00   $435,667.00   $432,333.00   $425,667.00
# 1  $653,431.00   $661,000.00   $662,667.00   $661,667.00   $654,167.00
# 2  $249,333.00   $251,000.00   $249,333.00   $243,333.00   $238,333.00
# 3  $277,355.00   $280,092.00   $278,425.00   $274,333.00   $271,667.00
# 4  $255,000.00   $262,667.00   $266,633.00   $260,633.00   $253,300.00
# 5  $249,000.00   $250,667.00   $251,000.00   $247,333.00   $243,967.00
# 6  $422,897.00   $425,885.00   $423,331.00   $414,998.00   $409,964.00
# 7  $289,429.00   $295,096.00   $297,167.00   $295,333.00   $295,000.00
# 8  $259,000.00   $263,667.00   $262,750.00   $260,733.00   $257,400.00
# 9  $474,900.00   $484,833.00   $484,000.00   $472,333.00   $461,667.00
#
#      11/30/2019    12/31/2019
# 0  $421,667.00   $420,000.00
# 1  $652,667.00   $654,333.00
# 2  $235,000.00   $234,333.00
# 3  $270,000.00   $271,833.00
# 4  $248,333.00   $249,000.00
# 5  $242,933.00   $245,449.00
# 6  $409,967.00   $416,967.00
# 7  $298,333.00   $301,000.00
# 8  $257,983.00   $260,000.00
# 9  $454,000.00   $457,333.00
#
# [10 rows x 37 columns]

# %%
Houston_df.set_index('RegionName')
Houston_df = avg_df[avg_df['RegionName'] == 'Houston, TX']

# %%
Houston_df
# Out:
#     RegionName     1/31/2017     2/28/2017     3/31/2017     4/30/2017  \
# 5  Houston, TX  $218,333.00   $217,000.00   $217,740.00   $223,574.00
#
#       5/31/2017     6/30/2017     7/31/2017     8/31/2017     9/30/2017  ...  \
# 5  $228,574.00   $231,833.00   $232,667.00   $231,667.00   $229,333.00   ...
#
#       3/31/2019     4/30/2019     5/31/2019     6/30/2019     7/31/2019  \
# 5  $232,227.00   $238,333.00   $244,333.00   $249,000.00   $250,667.00
#
#       8/31/2019     9/30/2019    10/31/2019    11/30/2019    12/31/2019
# 5  $251,000.00   $247,333.00   $243,967.00   $242,933.00   $245,449.00
#
# [1 rows x 37 columns]

# %%
#Houston_df.set_index('RegionName')

# %%
Houston_df.transpose()
# Out:
#                        5
# RegionName   Houston, TX
# 1/31/2017   $218,333.00
# 2/28/2017   $217,000.00
# 3/31/2017   $217,740.00
# 4/30/2017   $223,574.00
# 5/31/2017   $228,574.00
# 6/30/2017   $231,833.00
# 7/31/2017   $232,667.00
# 8/31/2017   $231,667.00
# 9/30/2017   $229,333.00
# 10/31/2017  $228,332.00
# 11/30/2017  $227,332.00
# 12/31/2017  $226,332.00
# 1/31/2018   $223,500.00
# 2/28/2018   $223,164.00
# 3/31/2018   $224,164.00
# 4/30/2018   $231,328.00
# 5/31/2018   $237,330.00
# 6/30/2018   $241,330.00
# 7/31/2018   $242,307.00
# 8/31/2018   $240,974.00
# 9/30/2018   $237,060.00
# 10/31/2018  $233,171.00
# 11/30/2018  $231,408.00
# 12/31/2018  $234,583.00
# 1/31/2019   $233,058.00
# 2/28/2019   $232,155.00
# 3/31/2019   $232,227.00
# 4/30/2019   $238,333.00
# 5/31/2019   $244,333.00
# 6/30/2019   $249,000.00
# 7/31/2019   $250,667.00
# 8/31/2019   $251,000.00
# 9/30/2019   $247,333.00
# 10/31/2019  $243,967.00
# 11/30/2019  $242,933.00
# 12/31/2019  $245,449.00

# %%
price_df = list(Houston_df.transpose().iloc[1:,0])

# %%
price_df
# Out:
# ['$218,333.00 ',
#  '$217,000.00 ',
#  '$217,740.00 ',
#  '$223,574.00 ',
#  '$228,574.00 ',
#  '$231,833.00 ',
#  '$232,667.00 ',
#  '$231,667.00 ',
#  '$229,333.00 ',
#  '$228,332.00 ',
#  '$227,332.00 ',
#  '$226,332.00 ',
#  '$223,500.00 ',
#  '$223,164.00 ',
#  '$224,164.00 ',
#  '$231,328.00 ',
#  '$237,330.00 ',
#  '$241,330.00 ',
#  '$242,307.00 ',
#  '$240,974.00 ',
#  '$237,060.00 ',
#  '$233,171.00 ',
#  '$231,408.00 ',
#  '$234,583.00 ',
#  '$233,058.00 ',
#  '$232,155.00 ',
#  '$232,227.00 ',
#  '$238,333.00 ',
#  '$244,333.00 ',
#  '$249,000.00 ',
#  '$250,667.00 ',
#  '$251,000.00 ',
#  '$247,333.00 ',
#  '$243,967.00 ',
#  '$242,933.00 ',
#  '$245,449.00 ']

# %%
date_df = Houston_df.transpose().index.values.tolist()

# %%
date_df.pop(0)
# Out:
# 'RegionName'

# %%
date_df
# Out:
# ['1/31/2017',
#  '2/28/2017',
#  '3/31/2017',
#  '4/30/2017',
#  '5/31/2017',
#  '6/30/2017',
#  '7/31/2017',
#  '8/31/2017',
#  '9/30/2017',
#  '10/31/2017',
#  '11/30/2017',
#  '12/31/2017',
#  '1/31/2018',
#  '2/28/2018',
#  '3/31/2018',
#  '4/30/2018',
#  '5/31/2018',
#  '6/30/2018',
#  '7/31/2018',
#  '8/31/2018',
#  '9/30/2018',
#  '10/31/2018',
#  '11/30/2018',
#  '12/31/2018',
#  '1/31/2019',
#  '2/28/2019',
#  '3/31/2019',
#  '4/30/2019',
#  '5/31/2019',
#  '6/30/2019',
#  '7/31/2019',
#  '8/31/2019',
#  '9/30/2019',
#  '10/31/2019',
#  '11/30/2019',
#  '12/31/2019']

# %%
x = date_df
y = price_df

# %%
plt.scatter(x, y)
plt.xlabel('Years')
plt.ylabel('Price in USD')
plt.show()

# %%
X = Houston_df.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([['Houston, TX'],
#        ['$218,333.00 '],
#        ['$217,000.00 '],
#        ['$217,740.00 '],
#        ['$223,574.00 ']], dtype=object)

# %%
X.shape
# Out:
# (37, 1)

# %%
y = Houston_df.values

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-6d10fe8973eb> in <module>
# ----> 1 model.fit(X, y)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     819                     ensure_min_samples=ensure_min_samples,
#     820                     ensure_min_features=ensure_min_features,
# --> 821                     estimator=estimator)
#     822     if multi_output:
#     823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\envs\mlenv\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Houston, TX'

# %%
y_pred = model.predict(x)
print(y_pred.shape)

# %%
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)

# %%
model = LinearRegression()

# %%
model.fit(x,y)

# %%
y_pred = model.predict(x)

# %%
housing_data_df.to_sql(name='housing', con=engine)
