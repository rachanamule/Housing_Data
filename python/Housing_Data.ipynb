# %%
import pandas as pd

# %%
forsale_data = "Resources1/Forsale_inventory.csv"
homevalue_index = "Resources1/Homevalue_index.csv"
homevalue_forecast = "Resources1/Homevalue_forecast.csv"
newlisting_inv = "Resources1/Newlisting_inventory.csv"
sale_price = "Resources1/Median_saleprice.csv"

# %%
# Create a DataFrame for the all the data sets . 
forsale_data_df = pd.read_csv(forsale_data)
homevalue_index_df = pd.read_csv(homevalue_index, index_col = False)
homevalue_forecast_df = pd.read_csv(homevalue_forecast)
newlisting_inv_df = pd.read_csv(newlisting_inv)
saleprice_df =  pd.read_csv(sale_price)
sale_states = pd.read_csv(sale_price)

# %% [markdown]
# ### Homevalue_index

# %%
# Drop dates from 2000-2017
#forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank', '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31'], axis = 1
homevalue_index_df.drop(homevalue_index_df.iloc[:, 5:221], inplace=True, axis=1)

# %%
homevalue_index_df= homevalue_index_df.drop(['RegionType', 'SizeRank'], axis = 1)
homevalue_index_df

# %%
#Dropping rows with null values 
homevalue_index_dfnew = homevalue_index_df.dropna()
homevalue_index_dfnew

# %% [markdown]
# ### FORSALE_INVENTORY

# %%
# Drop irrelevant columns
forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank'], axis = 1)

# %%
#Dropping rows with null values 
forsale_data_dfnew = forsale_data_df.dropna()
forsale_data_dfnew

# %%
#Getting rid of all states that are not Texas
drop_nontexas = forsale_data_dfnew[forsale_data_dfnew['StateName'] != 'TX'].index
forsale_data_dfnew.drop(drop_nontexas, inplace = True)

# %%
#Splitting the city and country in region name
forsale_data_dfnew['City'] = forsale_data_dfnew['RegionName'].str.split(',').apply(lambda x: x[0])

forsale_data_dfnew

# %%
# Drop irrelevant columns
forsale_data_dfnew = forsale_data_dfnew.drop(['RegionName', 'StateName'], axis = 1)
forsale_data_dfnew

# %%
# Moving the City column to the be the first column
forsale_data_dfnew = forsale_data_dfnew.reindex(columns=['City'] + list(forsale_data_dfnew.columns[:-1]))
forsale_data_dfnew

# %% [markdown]
# ### Newlisting_inventory

# %%
# Drop irrelevant columns
newlisting_inv_df = newlisting_inv_df.drop(['RegionType', 'SizeRank'], axis = 1)

# %%
#Dropping rows with null values 
newlisting_inv_dfnew = newlisting_inv_df.dropna()
newlisting_inv_dfnew

# %%
#Getting rid of all states that are not Texas
drop_nontexas1 = newlisting_inv_dfnew[newlisting_inv_dfnew['StateName'] != 'TX'].index
newlisting_inv_dfnew.drop(drop_nontexas1, inplace = True)

#Splitting the city and country in region name
newlisting_inv_dfnew['City'] = newlisting_inv_dfnew['RegionName'].str.split(',').apply(lambda x: x[0])

newlisting_inv_dfnew

# %%
# Drop irrelevant columns
newlisting_inv_dfnew = newlisting_inv_dfnew.drop(['RegionName', 'StateName'], axis = 1)
newlisting_inv_dfnew

# %%
# Moving the City column to the be the first column
newlisting_inv_dfnew = newlisting_inv_dfnew.reindex(columns= ['City'] + list(newlisting_inv_dfnew.columns[:-1]))
newlisting_inv_dfnew

# %% [markdown]
# ### Median Sale Price

# %%
# Drop dates from 2000-2017
#forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank', '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31'], axis = 1
saleprice_df.drop(saleprice_df.iloc[:, 5:110], inplace=True, axis=1)
saleprice_df

# %%
# Drop irrelevant columns
saleprice_df = saleprice_df.drop(['RegionType', 'SizeRank'], axis = 1)

# %%
#Dropping rows with null values 
saleprice_dfnew = saleprice_df.dropna()
saleprice_dfnew

# %%
saleprice_dfnew.drop(saleprice_dfnew.iloc[:, 20:100], inplace=True, axis=1)

# %%
saleprice_dfnew

# %%
#Getting rid of all states that are not Texas
#drop_nontexas2 = saleprice_dfnew[saleprice_dfnew['StateName'] != 'TX'].index
#saleprice_dfnew.drop(drop_nontexas2, inplace = True)

#Splitting the city and country in region name
saleprice_dfnew['City'] = saleprice_dfnew['RegionName'].str.split(',').apply(lambda x: x[0])

saleprice_dfnew

# %%
# Drop irrelevant columns
saleprice_dfnew = saleprice_dfnew.drop(['RegionName'], axis = 1)
saleprice_dfnew

# %%
# Moving the City column to the be the first column
saleprice_dfnew = saleprice_dfnew.reindex(columns= ['City'] + list(saleprice_dfnew.columns[:-1]))
saleprice_dfnew

# %%
# Export the forsale_inventory Dataframe as a new CSV file without the index.
forsale_data_dfnew.to_csv('CleanForsale.csv', index=False)

# %%
# Export the Newlisting_inv Dataframe as a new CSV file without the index.
newlisting_inv_dfnew.to_csv('CleanNewlisting.csv', index=False)

# %%
# Export the saleprice Dataframe as a new CSV file without the index.
saleprice_dfnew.to_csv('Clean_mediansale_price.csv', index=False)

# %%
State_ID = list(range(20))

# %%
State_ID

# %% [markdown]
# ## States csv

# %%
#forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank', '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31'], axis = 1
sale_states.drop(saleprice_df.iloc[:, 5:250], inplace=True, axis=1)
sale_states

# %%
#Dropping rows with null values 
sale_statesnew = sale_states.dropna()
sale_statesnew

# %%
# Drop irrelevant columns
sale_statesnew = sale_statesnew.drop(['RegionID', 'RegionType', 'StateName'], axis = 1)
sale_statesnew

# %%
#sale_statesnew.rename({SizeRank: CityID}, axis='index')
sale_statesnew.columns = ['CityID', 'RegionName']
sale_statesnew

# %%
# Export the saleprice Dataframe as a new CSV file without the index.
sale_statesnew.to_csv('states.csv', index=False)

# %% [markdown]
# ### Years 2017-2019 CSV

# %%
# Drop dates from 2000-2017
#forsale_data_df = forsale_data_df.drop(['RegionType', 'SizeRank', '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31'], axis = 1
saleprice_df.drop(saleprice_df.iloc[:, 5:110], inplace=True, axis=1)
saleprice_df
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 90    394528        90                   Daytona Beach, FL        Msa
# 91    394531        91                      Des Moines, IA        Msa
# 92    395006       100                           Provo, UT        Msa
# 93    394549       104                          Durham, NC        Msa
# 94    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2017-01-31  2017-02-28  2017-03-31  2017-04-30  2017-05-31  ...  \
# ...

# %%
#Dropping rows with null values 
saleprices_ = saleprice_df.dropna()
saleprices_
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# 5     394974         5                    Philadelphia, PA        Msa
# ..       ...       ...                                 ...        ...
# 90    394528        90                   Daytona Beach, FL        Msa
# 91    394531        91                      Des Moines, IA        Msa
# 92    395006       100                           Provo, UT        Msa
# 93    394549       104                          Durham, NC        Msa
# 94    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2017-01-31  2017-02-28  2017-03-31  2017-04-30  2017-05-31  ...  \
# ...

# %%
# Drop irrelevant columns
saleprice_clean = saleprices_.drop(['RegionID', 'RegionType', 'StateName', 'SizeRank'], axis = 1)
saleprice_clean
# Out:
#                             RegionName  2017-01-31  2017-02-28  2017-03-31  \
# 1                         New York, NY    386000.0    387000.0    387000.0
# 2   Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# 3                          Chicago, IL    211333.0    211333.0    216200.0
# 4                Dallas-Fort Worth, TX    236500.0    239000.0    242333.0
# 5                     Philadelphia, PA    226333.0    221333.0    217667.0
# ..                                 ...         ...         ...         ...
# 90                   Daytona Beach, FL    174667.0    173000.0    174667.0
# 91                      Des Moines, IA    181667.0    179333.0    177867.0
# 92                           Provo, UT    258300.0    261633.0    262550.0
# 93                          Durham, NC    237667.0    240750.0    238583.0
# 94                    Fort Collins, CO    342650.0    345783.0    345783.0
#
# ...

# %%
#saleprice_clean.columns = saleprice_clean.columns.str.replace('SizeRank', 'CityID')

# %%
saleprice_clean
# Out:
#                             RegionName  2017-01-31  2017-02-28  2017-03-31  \
# 1                         New York, NY    386000.0    387000.0    387000.0
# 2   Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# 3                          Chicago, IL    211333.0    211333.0    216200.0
# 4                Dallas-Fort Worth, TX    236500.0    239000.0    242333.0
# 5                     Philadelphia, PA    226333.0    221333.0    217667.0
# ..                                 ...         ...         ...         ...
# 90                   Daytona Beach, FL    174667.0    173000.0    174667.0
# 91                      Des Moines, IA    181667.0    179333.0    177867.0
# 92                           Provo, UT    258300.0    261633.0    262550.0
# 93                          Durham, NC    237667.0    240750.0    238583.0
# 94                    Fort Collins, CO    342650.0    345783.0    345783.0
#
# ...

# %%
saleprice_2017 = saleprice_clean

# %%
saleprice_2017.drop(saleprice_2017.iloc[:, 37:100], inplace=True, axis=1)

# %%
saleprice_2017
# Out:
#                             RegionName  2017-01-31  2017-02-28  2017-03-31  \
# 1                         New York, NY    386000.0    387000.0    387000.0
# 2   Los Angeles-Long Beach-Anaheim, CA    571833.0    570167.0    577498.0
# 3                          Chicago, IL    211333.0    211333.0    216200.0
# 4                Dallas-Fort Worth, TX    236500.0    239000.0    242333.0
# 5                     Philadelphia, PA    226333.0    221333.0    217667.0
# ..                                 ...         ...         ...         ...
# 90                   Daytona Beach, FL    174667.0    173000.0    174667.0
# 91                      Des Moines, IA    181667.0    179333.0    177867.0
# 92                           Provo, UT    258300.0    261633.0    262550.0
# 93                          Durham, NC    237667.0    240750.0    238583.0
# 94                    Fort Collins, CO    342650.0    345783.0    345783.0
#
# ...

# %%
# Export the saleprice Dataframe for 2017-2019 as a new CSV file without the index.
saleprice_2017.to_csv('2017-2019_price.csv', index=False)

# %% [markdown]
# ### 2020 CSV

# %%
saleprices_
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# 5     394974         5                    Philadelphia, PA        Msa
# ..       ...       ...                                 ...        ...
# 90    394528        90                   Daytona Beach, FL        Msa
# 91    394531        91                      Des Moines, IA        Msa
# 92    395006       100                           Provo, UT        Msa
# 93    394549       104                          Durham, NC        Msa
# 94    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2017-01-31  2017-02-28  2017-03-31  2017-04-30  2017-05-31  ...  \
# ...

# %%
# Drop irrelevant columns
saleprice_2020 = saleprices_.drop(['RegionID', 'RegionType', 'StateName', 'SizeRank'], axis = 1)

# %%
#saleprice_2020.columns = saleprice_2020.columns.str.replace('SizeRank', 'CityID')

# %%
saleprice_2020.drop(saleprice_2020.iloc[:, 1:37], inplace=True, axis=1)

# %%
saleprice_2020
# Out:
#                             RegionName  2020-01-31  2020-02-29  2020-03-31  \
# 1                         New York, NY    421667.0    423333.0    424983.0
# 2   Los Angeles-Long Beach-Anaheim, CA    656500.0    660417.0    667800.0
# 3                          Chicago, IL    231333.0    229667.0    235333.0
# 4                Dallas-Fort Worth, TX    270500.0    271833.0    273333.0
# 5                     Philadelphia, PA    249000.0    248000.0    249167.0
# ..                                 ...         ...         ...         ...
# 90                   Daytona Beach, FL    227297.0    226633.0    227333.0
# 91                      Des Moines, IA    216681.0    210327.0    209250.0
# 92                           Provo, UT    332332.0    335000.0    336667.0
# 93                          Durham, NC    297333.0    293833.0    300667.0
# 94                    Fort Collins, CO    391500.0    394167.0    394216.0
#
# ...

# %%
# Export the saleprice Dataframe for 2017-2019 as a new CSV file without the index.
saleprice_2020.to_csv('2020-2021_price.csv', index=False)

# %% [markdown]
# ### Avg Prices 2020

# %%
df_2020 = saleprice_2020.set_index('RegionName')

# %%
df_2020['2020']=None
df_2020
# Out:
#                                     2020-01-31  2020-02-29  2020-03-31  \
# RegionName
# New York, NY                          421667.0    423333.0    424983.0
# Los Angeles-Long Beach-Anaheim, CA    656500.0    660417.0    667800.0
# Chicago, IL                           231333.0    229667.0    235333.0
# Dallas-Fort Worth, TX                 270500.0    271833.0    273333.0
# Philadelphia, PA                      249000.0    248000.0    249167.0
# ...                                        ...         ...         ...
# Daytona Beach, FL                     227297.0    226633.0    227333.0
# Des Moines, IA                        216681.0    210327.0    209250.0
# Provo, UT                             332332.0    335000.0    336667.0
# Durham, NC                            297333.0    293833.0    300667.0
# Fort Collins, CO                      391500.0    394167.0    394216.0
#
#                                     2020-04-30  2020-05-31  2020-06-30  \
# RegionName
# ...

# %%
avg = []

for x in range(len(df_2020)):
    #print(df.iloc[x,1])
    #city_avg = []
    
    #for y in range(12):
    
        #city_avg.append(df_2017.iloc[x,y])
    avg.append(int((df_2020.iloc[x, 1] + df_2020.iloc[x, 2] + df_2020.iloc[x, 3] + df_2020.iloc[x, 4] + df_2020.iloc[x, 5] + df_2020.iloc[x, 6] + df_2020.iloc[x, 7] + df_2020.iloc[x, 8] + df_2020.iloc[x, 9] + df_2020.iloc[x, 10] + df_2020.iloc[x, 11] + df_2020.iloc[x, 12]) / 12))

df_2020['2020']= avg
#avg


avg_2021 =[]
for x in range(len(df_2020)): 
    avg_2021.append(int((df_2020.iloc[x, 13] + df_2020.iloc[x, 14] + df_2020.iloc[x, 15] + df_2020.iloc[x, 16] + df_2020.iloc[x, 17] + df_2020.iloc[x, 18] + df_2020.iloc[x, 19] + df_2020.iloc[x, 20]) / 8))
df_2020['2021']= avg_2021

# %%
df_2020.drop(df_2020.iloc[:, 1:20], inplace=True, axis=1)

# %%
df_2020
# Out:
#                                     2020-01-31    2020    2021
# RegionName
# New York, NY                          421667.0  448065  492570
# Los Angeles-Long Beach-Anaheim, CA    656500.0  699588  778865
# Chicago, IL                           231333.0  255368  274527
# Dallas-Fort Worth, TX                 270500.0  289596  326257
# Philadelphia, PA                      249000.0  270493  283647
# ...                                        ...     ...     ...
# Daytona Beach, FL                     227297.0  237567  265778
# Des Moines, IA                        216681.0  227195  242528
# Provo, UT                             332332.0  357802  421636
# Durham, NC                            297333.0  305591  338338
# Fort Collins, CO                      391500.0  408106  443385
#
# [94 rows x 3 columns]

# %%
df_2020 = df_2020.drop(['2020-01-31'], axis = 1)
df_2020
# Out:
#                                       2020    2021
# RegionName
# New York, NY                        448065  492570
# Los Angeles-Long Beach-Anaheim, CA  699588  778865
# Chicago, IL                         255368  274527
# Dallas-Fort Worth, TX               289596  326257
# Philadelphia, PA                    270493  283647
# ...                                    ...     ...
# Daytona Beach, FL                   237567  265778
# Des Moines, IA                      227195  242528
# Provo, UT                           357802  421636
# Durham, NC                          305591  338338
# Fort Collins, CO                    408106  443385
#
# [94 rows x 2 columns]

# %%
# Export the saleprice_avg Dataframe for 2017-2019 as a new CSV file without the index.
df_2020.to_csv('saleprice_2020_avg.csv', index=True)

# %% [markdown]
# ### Avg Prices 2021

# %%
df_2021 = saleprice_2020.set_index('RegionName')

# %%
df_2021['2021_Avg']=None
df_2021
# Out:
#                                     2020-01-31  2020-02-29  2020-03-31  \
# RegionName
# New York, NY                          421667.0    423333.0    424983.0
# Los Angeles-Long Beach-Anaheim, CA    656500.0    660417.0    667800.0
# Chicago, IL                           231333.0    229667.0    235333.0
# Dallas-Fort Worth, TX                 270500.0    271833.0    273333.0
# Philadelphia, PA                      249000.0    248000.0    249167.0
# ...                                        ...         ...         ...
# Daytona Beach, FL                     227297.0    226633.0    227333.0
# Des Moines, IA                        216681.0    210327.0    209250.0
# Provo, UT                             332332.0    335000.0    336667.0
# Durham, NC                            297333.0    293833.0    300667.0
# Fort Collins, CO                      391500.0    394167.0    394216.0
#
#                                     2020-04-30  2020-05-31  2020-06-30  \
# RegionName
# ...

# %%
avg = []
for x in range(len(df_2021)):
    #print(df.iloc[x,1])
    #city_avg = []
    
    #for y in range(12):
    
        #city_avg.append(df_2017.iloc[x,y])
    avg.append(int((df_2021.iloc[x, 1] + df_2021.iloc[x, 2] + df_2021.iloc[x, 3] + df_2021.iloc[x, 4] + df_2021.iloc[x, 5] + df_2021.iloc[x, 6] + df_2021.iloc[x, 7] + df_2021.iloc[x, 8]) / 12))


df_2021['2021_Avg']= avg
#avg
avg_2021 =[]
for x in range(len(df_)):
    #print(df.iloc[x,1])
    #city_avg = []
    #for y in range(12):
        #city_avg.append(df_2017.iloc[x,y])
    avg_2019.append(int((df.iloc[x, 25] + df.iloc[x, 26] + df.iloc[x, 27] + df.iloc[x, 28] + df.iloc[x, 29] + df.iloc[x, 30] + df.iloc[x, 31] + df.iloc[x, 32] + df.iloc[x, 33] + df.iloc[x, 34] + df.iloc[x, 35] + df.iloc[x, 36]) / 12))
df['2019']= avg_2019

# %%
df_2021.drop(df_2021.iloc[:, 1:20], inplace=True, axis=1)

# %%
df_2021
# Out:
#                                     2020-01-31  2021_Avg
# RegionName
# New York, NY                          421667.0    291829
# Los Angeles-Long Beach-Anaheim, CA    656500.0    455227
# Chicago, IL                           231333.0    167513
# Dallas-Fort Worth, TX                 270500.0    189832
# Philadelphia, PA                      249000.0    177611
# ...                                        ...       ...
# Daytona Beach, FL                     227297.0    155002
# Des Moines, IA                        216681.0    148325
# Provo, UT                             332332.0    231986
# Durham, NC                            297333.0    202534
# Fort Collins, CO                      391500.0    267660
#
# [94 rows x 2 columns]

# %%
df_2021 = df_2021.drop(['2020-01-31'], axis = 1)
df_2021
# Out:
#                                     2021_Avg
# RegionName
# New York, NY                          291829
# Los Angeles-Long Beach-Anaheim, CA    455227
# Chicago, IL                           167513
# Dallas-Fort Worth, TX                 189832
# Philadelphia, PA                      177611
# ...                                      ...
# Daytona Beach, FL                     155002
# Des Moines, IA                        148325
# Provo, UT                             231986
# Durham, NC                            202534
# Fort Collins, CO                      267660
#
# [94 rows x 1 columns]

# %%
df_2020_Avgs = [df_2021, df_2020]

# %%
df_2020_Avgs
# Out:
# [                                    2021_Avg
#  RegionName
#  New York, NY                          291829
#  Los Angeles-Long Beach-Anaheim, CA    455227
#  Chicago, IL                           167513
#  Dallas-Fort Worth, TX                 189832
#  Philadelphia, PA                      177611
#  ...                                      ...
#  Daytona Beach, FL                     155002
#  Des Moines, IA                        148325
#  Provo, UT                             231986
#  Durham, NC                            202534
#  Fort Collins, CO                      267660
#
#  [94 rows x 1 columns],
#                                      2020Avg
#  RegionName
#  New York, NY                         448065
#  Los Angeles-Long Beach-Anaheim, CA   699588
#  Chicago, IL                          255368
#  Dallas-Fort Worth, TX                289596
#  Philadelphia, PA                     270493
#  ...                                     ...
# ...

# %%
avgs_2020 = pd.concat(df_2020_Avgs)

# %%
avgs_2020
# Out:
#                                     2021_Avg   2020Avg
# RegionName
# New York, NY                        291829.0       NaN
# Los Angeles-Long Beach-Anaheim, CA  455227.0       NaN
# Chicago, IL                         167513.0       NaN
# Dallas-Fort Worth, TX               189832.0       NaN
# Philadelphia, PA                    177611.0       NaN
# ...                                      ...       ...
# Daytona Beach, FL                        NaN  237567.0
# Des Moines, IA                           NaN  227195.0
# Provo, UT                                NaN  357802.0
# Durham, NC                               NaN  305591.0
# Fort Collins, CO                         NaN  408106.0
#
# [188 rows x 2 columns]
